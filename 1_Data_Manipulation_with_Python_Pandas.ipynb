# %% [markdown]
# <a href="https://colab.research.google.com/github/mojahid-t17/Machine-Learning/blob/main/1_Data_Manipulation_with_Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # install pandas: !pip install pandas
# # A Series is essentially a column, and a DataFrame is a multi-dimensional table made up of a collection of Series.

# %%
import pandas as pd
# series
x=[10,20,30,40]
series=pd.Series(x)
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# change row name
series2=pd.Series(x, index=['a','b','c','d'])

print(series2)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
a=pd.Series(12)
print(a)
b=pd.Series(10, index=[1,2,3,4])
print(b)
# Out:
# 0    12
# dtype: int64
# 1    10
# 2    10
# 3    10
# 4    10
# dtype: int64

# %%
#dataframe:
name=['harry','bob','jeny','tomas']
df1=pd.DataFrame(name)
df1
# Out:
#        0
# 0  harry
# 1    bob
# 2   jeny
# 3  tomas

# %%
row,col=df1.shape

# %%
row
# Out:
# 4

# %%
col
# Out:
# 1

# %%
df1.shape
# Out:
# (4, 1)

# %%
#change row and columns name:
df1=pd.DataFrame(name,index=['n1','n2','n3','n4'],columns=['student_name'])
df1
# Out:
#    student_name
# n1        harry
# n2          bob
# n3         jeny
# n4        tomas

# %%
sub=['physics','chemistry','biology','higher math']
# concat the subject with name in a dataframe. create a df by two list
df2=pd.DataFrame(zip(name,sub),columns=['student-name','subject'])
df2
# Out:
#   student-name      subject
# 0        harry      physics
# 1          bob    chemistry
# 2         jeny      biology
# 3        tomas  higher math

# %%
#create dataframe with dictonary
data={
    'name':['alex','david','robert', 'jack', 'molina'], 'rank':[2,5,3,1,7], 'marks':[90,34,53,25,69]
}
df3=pd.DataFrame(data)
df3
# Out:
#      name  rank  marks
# 0    alex     2     90
# 1   david     5     34
# 2  robert     3     53
# 3    jack     1     25
# 4  molina     7     69

# %%
#find the columns name of a dataframe
col=df3.columns
col
# Out:
# Index(['name', 'rank', 'marks'], dtype='object')

# %%
#print the columns by loop
for col in df3:
  print(col)
# Out:
# name
# rank
# marks

# %%
#read csv file:
df=pd.read_csv('/content/healthcare_dataset.csv')
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.head() #display only first 5 row
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.tail() #display last 5 row
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.describe()  #Statistical Analysis
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
#print a specific column
df.Age
# Out:
# 0        30
# 1        62
# 2        76
# 3        28
# 4        43
#          ..
# 55495    42
# 55496    61
# 55497    38
# 55498    43
# 55499    53
# Name: Age, Length: 55500, dtype: int64

# %%
df['Room Number']
# Out:
# 0        328
# 1        265
# 2        205
# 3        450
# 4        458
#         ...
# 55495    417
# 55496    316
# 55497    347
# 55498    321
# 55499    448
# Name: Room Number, Length: 55500, dtype: int64

# %%
#multiple column
df[['Room Number','Age']]
# Out:
#        Room Number  Age
# 0              328   30
# 1              265   62
# 2              205   76
# 3              450   28
# 4              458   43
# ...            ...  ...
# 55495          417   42
# 55496          316   61
# 55497          347   38
# 55498          321   43
# 55499          448   53
#
# [55500 rows x 2 columns]

# %%
#sorting a column by ascending order
df['Room Number'].sort_values()
# Out:
# 41362    101
# 23081    101
# 37024    101
# 989      101
# 25554    101
#         ...
# 42972    500
# 22691    500
# 15742    500
# 21107    500
# 1868     500
# Name: Room Number, Length: 55500, dtype: int64

# %%
#sorting descending order
df['Room Number'].sort_values(ascending=False)
# Out:
# 11414    500
# 21107    500
# 42972    500
# 28065    500
# 8944     500
#         ...
# 16271    101
# 12080    101
# 20386    101
# 37709    101
# 34152    101
# Name: Room Number, Length: 55500, dtype: int64

# %%
# sort the full dataframe based on Room number column
df.sort_values('Room Number')
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 41362      VictORIa daVIs   38  Female         B+            Asthma
# 23081       dAniel GaRcIa   74    Male         B-            Cancer
# 37024        tAyloR eLLis   79    Male         A-            Asthma
# 989    MRS. laUrEn morgaN   83  Female         B-          Diabetes
# 25554       anThonY GReEN   43  Female         O-            Cancer
# ...                   ...  ...     ...        ...               ...
# 42972       jOHn WhiTAKer   25  Female         O-         Arthritis
# 22691      REBECCa mArTiN   24  Female         O+          Diabetes
# 15742        bReNT BurTON   21  Female         B-      Hypertension
# 21107      CHeLSea BROOkS   77    Male         O-          Diabetes
# 1868       roGeR baRTLeTT   57  Female         O+         Arthritis
#
#       Date of Admission             Doctor                       Hospital  \
# 41362        2022-10-01     Thomas Johnson                  Group Russell
# ...

# %%
#remove the duplicate elements of the csv file
df=df.drop_duplicates()

# %%
# find nulls in the dataframe
pd.isnull(df)
# Out:
#         Name    Age  Gender  Blood Type  Medical Condition  Date of Admission  \
# 0      False  False   False       False              False              False
# 1      False  False   False       False              False              False
# 2      False  False   False       False              False              False
# 3      False  False   False       False              False              False
# 4      False  False   False       False              False              False
# ...      ...    ...     ...         ...                ...                ...
# 55495  False  False   False       False              False              False
# 55496  False  False   False       False              False              False
# 55497  False  False   False       False              False              False
# 55498  False  False   False       False              False              False
# 55499  False  False   False       False              False              False
#
# ...

# %%
#total null
pd.isnull(df).sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
#remove the null values
# df=df.dropna()   #df.dropna(axis=1)  ...> drop columns with null values

# %%
#fill the null values with a string
from textwrap import fill
df.fillna('someting')
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
#subsetting rows
#find the Age above 50
df['Age']>50
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 55495    False
# 55496     True
# 55497    False
# 55498    False
# 55499     True
# Name: Age, Length: 54966, dtype: bool

# %%
# based on  df['Age']>50 subsetting the whole dataframe
df[df['Age']>50] #filter only the rows where age is above 50
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 8       JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9      ChRISTopher BerG   58  Female        AB-            Cancer
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# ...                 ...  ...     ...        ...               ...
# 55492  LAuREn MCcormIcK   51    Male         O+         Arthritis
# 55493      gLoRIA BOWen   57  Female         B-         Arthritis
# 55494     JEssIcA WHiTe   67    Male         O+         Arthritis
# 55496        KYle pEREz   61  Female        AB-           Obesity
# 55499      jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor         Hospital Insurance Provider  \
# 1            2019-08-20   Samantha Davies          Kim Inc           Medicare
# ...

# %%
#subsetting by string
df['Gender']=='Male'
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 55495    False
# 55496    False
# 55497    False
# 55498     True
# 55499    False
# Name: Gender, Length: 54966, dtype: bool

# %%
#subsetting using multiple cols
df[(df['Age']>50 ) & (df['Gender']=='Male')]
# Out:
#                       Name  Age Gender Blood Type Medical Condition  \
# 1             LesLie TErRy   62   Male         A+           Obesity
# 8          JASmINe aGuIlaR   82   Male        AB+            Asthma
# 10        mIchElLe daniELs   72   Male         O+            Cancer
# 19          dANIEL schmIdt   63   Male         B+            Asthma
# 23     dR. EilEEn thomPsoN   59   Male         A+            Asthma
# ...                    ...  ...    ...        ...               ...
# 55477          sUE edWardS   56   Male         O+      Hypertension
# 55489       ANdrEw AGUIlaR   69   Male         O-         Arthritis
# 55490     STepHAniE oliVer   82   Male         B-            Cancer
# 55492     LAuREn MCcormIcK   51   Male         O+         Arthritis
# 55494        JEssIcA WHiTe   67   Male         O+         Arthritis
#
#       Date of Admission             Doctor                Hospital  \
# 1            2019-08-20    Samantha Davies                 Kim Inc
# ...

# %%
#multiple attribute in a single col
df[(df['Medical Condition']=='Cancer') | (df['Medical Condition']=='Asthma')]
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0            Bobby JacksOn   30    Male         B-            Cancer
# 4            adrIENNE bEll   43  Female        AB+            Cancer
# 5            EMILY JOHNSOn   36    Male         A+            Asthma
# 7       CHrisTInA MARtinez   20  Female         A+            Cancer
# 8          JASmINe aGuIlaR   82    Male        AB+            Asthma
# ...                    ...  ...     ...        ...               ...
# 55482          LUIs BaRbEr   58  Female         B+            Asthma
# 55485  grEgorY jOHnSon dDs   41  Female         O-            Asthma
# 55486        AngelA LEstER   83  Female         B+            Asthma
# 55490     STepHAniE oliVer   82    Male         B-            Cancer
# 55495    eLIZABeTH jaCkSOn   42  Female         O+            Asthma
#
#       Date of Admission              Doctor                     Hospital  \
# ...

# %%
#subsetting using isin()
df['Medical Condition'].isin(['Cance','Asthma	']) #again use df[] to subset the dataframe based on this condition
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55495    False
# 55496    False
# 55497    False
# 55498    False
# 55499    False
# Name: Medical Condition, Length: 54966, dtype: bool
